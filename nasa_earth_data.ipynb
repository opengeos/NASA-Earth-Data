# %% [markdown]
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/NASA-Earth-Data/blob/main/nasa_earth_data.ipynb)
# [![License](https://img.shields.io/badge/License-MIT-yellow.svg)](https://opensource.org/licenses/MIT)

# %%
import pandas as pd

# %%
url = 'https://github.com/opengeos/NASA-Earth-Data/raw/main/nasa_earth_data.tsv'
df = pd.read_csv(url, sep='\t')

# %%
df
# Out:
#                    ShortName  \
# 0         2009oct_Chesapeake
# 1                  2dimpacts
# 2                       AAOT
# 3                     AA_L2A
# 4     ABI_G16-STAR-L2P-v2.70
# ...                      ...
# 9038             wilhend_687
# 9039            willmott_673
# 9040           wisperimpacts
# 9041       woody_biomass_657
# 9042              wrfimpacts
#
#                                              EntryTitle  \
# 0       Chesapeake Bay measurements during October 2009
# 1     Two-Dimensional Video Disdrometer (2DVD) IMPAC...
# 2                 Acqua Alta Oceanographic Tower (AAOT)
# 3     AMSR/ADEOS-II L2A Global Swath Spatially-Resam...
# 4     GHRSST NOAA/STAR GOES-16 ABI L2P America Regio...
# ...                                                 ...
# 9038  LBA Regional Vegetation and Soils, 1-Degree (W...
# 9039  LBA Regional Climate Data, 0.5-Degree Grid, 19...
# 9040  Water Isotope System for Precipitation and Ent...
# 9041  Woody Biomass for Eastern U.S. Forests, 1983-1996
# 9042  Weather Research and Forecasting (WRF) Model I...
#
#                                              DOI              concept-id  \
# 0     10.5067/SeaBASS/2009OCT_CHESAPEAKE/DATA001     C1633360083-OB_DAAC
# 1                   10.5067/IMPACTS/2DVD/DATA101   C1995564612-GHRC_DAAC
# 2                   10.5067/SeaBASS/AAOT/DATA001     C1633360084-OB_DAAC
# 3               10.5067/ADEOS-II/AMSR/AA_L2A.001   C1241435536-NSIDC_ECS
# 4                            10.5067/GHG16-2PO27     C2036877465-POCLOUD
# ...                                          ...                     ...
# 9038                        10.3334/ORNLDAAC/687  C2777328977-ORNL_CLOUD
# 9039                        10.3334/ORNLDAAC/673  C2779732234-ORNL_CLOUD
# 9040              10.5067/IMPACTS/WISPER/DATA101   C2175816611-GHRC_DAAC
# 9041                        10.3334/ORNLDAAC/657  C2808093948-ORNL_CLOUD
# 9042                 10.5067/IMPACTS/WRF/DATA101   C1995874860-GHRC_DAAC
#
#      provider-id                                           s3-links  \
# 0        OB_DAAC                                                NaN
# 1      GHRC_DAAC                  ['ghrcw-protected/2dimpacts__1/']
# 2        OB_DAAC                                                NaN
# 3      NSIDC_ECS                                                NaN
# 4        POCLOUD  ['podaac-ops-cumulus-protected/ABI_G16-STAR-L2...
# ...          ...                                                ...
# 9038  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/lba/land_us...
# 9039  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/lba/physica...
# 9040   GHRC_DAAC              ['ghrcw-protected/wisperimpacts__1/']
# 9041  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/global_vege...
# 9042   GHRC_DAAC                 ['ghrcw-protected/wrfimpacts__1/']
#
#                Creator                                          Publisher  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN  NASA National Snow and Ice Data Center Distrib...
# 4     NOAA/NESDIS/STAR                                            PO.DAAC
# ...                ...                                                ...
# 9038               NaN                                                NaN
# 9039               NaN                                                NaN
# 9040               NaN                                                NaN
# 9041               NaN                                                NaN
# 9042               NaN                                                NaN
#
#                    ReleaseDate            ReleasePlace Version  \
# 0                          NaN                     NaN     NaN
# 1                          NaN                     NaN     NaN
# 2                          NaN                     NaN     NaN
# 3                          NaN                     NaN       1
# 4     2019-05-15T00:00:00.000Z  Camp Springs, MD (USA)    2.70
# ...                        ...                     ...     ...
# 9038                       NaN                     NaN     NaN
# 9039                       NaN                     NaN     NaN
# 9040                       NaN                     NaN     NaN
# 9041                       NaN                     NaN     NaN
# 9042                       NaN                     NaN     NaN
#
#                                                 Linkage
# 0     https://doi.org/10.5067/SeaBASS/2009OCT_CHESAP...
# 1          https://doi.org/10.5067/IMPACTS/2DVD/DATA101
# 2          https://doi.org/10.5067/SeaBASS/AAOT/DATA001
# 3      https://doi.org/10.5067/ADEOS-II/AMSR/AA_L2A.001
# 4                   https://doi.org/10.5067/GHG16-2PO27
# ...                                                 ...
# 9038               https://doi.org/10.3334/ORNLDAAC/687
# 9039               https://doi.org/10.3334/ORNLDAAC/673
# 9040     https://doi.org/10.5067/IMPACTS/WISPER/DATA101
# 9041               https://doi.org/10.3334/ORNLDAAC/657
# 9042        https://doi.org/10.5067/IMPACTS/WRF/DATA101
#
# [9043 rows x 12 columns]
