# %% [markdown]
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/NASA-Earth-Data/blob/main/nasa_earth_data.ipynb)
# [![License](https://img.shields.io/badge/License-MIT-yellow.svg)](https://opensource.org/licenses/MIT)

# %%
import pandas as pd

# %%
url = "https://github.com/opengeos/NASA-Earth-Data/raw/main/nasa_earth_data.tsv"
df = pd.read_csv(url, sep="\t")

# %%
df
# Out:
#                    ShortName  \
# 0         2009oct_Chesapeake
# 1                  2dimpacts
# 2                       AAOT
# 3                     AA_L2A
# 4     ABI_G16-STAR-L2P-v2.70
# ...                      ...
# 9013             wilhend_687
# 9014            willmott_673
# 9015           wisperimpacts
# 9016       woody_biomass_657
# 9017              wrfimpacts
#
#                                              EntryTitle  \
# 0       Chesapeake Bay measurements during October 2009
# 1     Two-Dimensional Video Disdrometer (2DVD) IMPAC...
# 2                 Acqua Alta Oceanographic Tower (AAOT)
# 3     AMSR/ADEOS-II L2A Global Swath Spatially-Resam...
# 4     GHRSST NOAA/STAR GOES-16 ABI L2P America Regio...
# ...                                                 ...
# 9013  LBA Regional Vegetation and Soils, 1-Degree (W...
# 9014  LBA Regional Climate Data, 0.5-Degree Grid, 19...
# 9015  Water Isotope System for Precipitation and Ent...
# 9016  Woody Biomass for Eastern U.S. Forests, 1983-1996
# 9017  Weather Research and Forecasting (WRF) Model I...
#
#                                              DOI              concept-id  \
# 0     10.5067/SeaBASS/2009OCT_CHESAPEAKE/DATA001     C1633360083-OB_DAAC
# 1                   10.5067/IMPACTS/2DVD/DATA101   C1995564612-GHRC_DAAC
# 2                   10.5067/SeaBASS/AAOT/DATA001     C1633360084-OB_DAAC
# 3               10.5067/ADEOS-II/AMSR/AA_L2A.001   C1241435536-NSIDC_ECS
# 4                            10.5067/GHG16-2PO27     C2036877465-POCLOUD
# ...                                          ...                     ...
# 9013                        10.3334/ORNLDAAC/687  C2777328977-ORNL_CLOUD
# 9014                        10.3334/ORNLDAAC/673  C2779732234-ORNL_CLOUD
# 9015              10.5067/IMPACTS/WISPER/DATA101   C2175816611-GHRC_DAAC
# 9016                        10.3334/ORNLDAAC/657  C2808093948-ORNL_CLOUD
# 9017                 10.5067/IMPACTS/WRF/DATA101   C1995874860-GHRC_DAAC
#
#      provider-id                                           s3-links  \
# 0        OB_DAAC                                                NaN
# 1      GHRC_DAAC                  ['ghrcw-protected/2dimpacts__1/']
# 2        OB_DAAC                                                NaN
# 3      NSIDC_ECS                                                NaN
# 4        POCLOUD  ['podaac-ops-cumulus-protected/ABI_G16-STAR-L2...
# ...          ...                                                ...
# 9013  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/lba/land_us...
# 9014  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/lba/physica...
# 9015   GHRC_DAAC              ['ghrcw-protected/wisperimpacts__1/']
# 9016  ORNL_CLOUD  ['s3://ornl-cumulus-prod-protected/global_vege...
# 9017   GHRC_DAAC                 ['ghrcw-protected/wrfimpacts__1/']
#
#        bbox-crs                                               bbox  \
# 0     CARTESIAN                       [-180.0, -90.0, 180.0, 90.0]
# 1     CARTESIAN             [-75.4912, 37.9194, -75.4462, 37.9543]
# 2     CARTESIAN                       [-180.0, -90.0, 180.0, 90.0]
# 3     CARTESIAN                       [-180.0, -90.0, 180.0, 90.0]
# 4     CARTESIAN                       [-135.0, -59.0, -15.0, 59.0]
# ...         ...                                                ...
# 9013  CARTESIAN                        [-85.0, -25.0, -30.0, 10.0]
# 9014  CARTESIAN                        [-85.0, -25.0, -30.0, 10.0]
# 9015  CARTESIAN  [-95.2426928, 33.2614038, -67.8781539, 48.2369...
# 9016  CARTESIAN                        [-100.0, 25.0, -60.0, 50.0]
# 9017  CARTESIAN  [-114.20199584960938, 22.970565795898438, -53....
#
#                                          horizontal_res  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     [{'XDimension': 2000.0, 'YDimension': 2000.0, ...
# ...                                                 ...
# 9013                                                NaN
# 9014                                                NaN
# 9015                                                NaN
# 9016                                                NaN
# 9017                                                NaN
#
#                     start-time                  end-time           Creator  \
# 0         2009-10-12T00:00:02Z                       NaN               NaN
# 1     2020-01-15T01:37:06.000Z  2020-02-28T20:41:44.000Z               NaN
# 2         1999-08-03T00:00:02Z                       NaN               NaN
# 3     2003-01-18T00:00:00.000Z  2003-10-24T23:59:59.999Z               NaN
# 4     2017-12-15T00:00:00.000Z                       NaN  NOAA/NESDIS/STAR
# ...                        ...                       ...               ...
# 9013  1900-01-01T00:00:00.000Z  1999-12-31T23:59:59.000Z               NaN
# 9014  1960-01-01T00:00:00.000Z  1990-12-31T23:59:59.000Z               NaN
# 9015  2020-01-18T18:01:40.000Z  2023-02-28T15:35:37.000Z               NaN
# 9016  1983-01-01T00:00:00.000Z  1996-12-31T23:59:59.000Z               NaN
# 9017  2020-01-12T00:00:00.000Z  2023-03-04T14:59:59.000Z               NaN
#
#                                               Publisher  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     NASA National Snow and Ice Data Center Distrib...
# 4                                               PO.DAAC
# ...                                                 ...
# 9013                                                NaN
# 9014                                                NaN
# 9015                                                NaN
# 9016                                                NaN
# 9017                                                NaN
#
#                    ReleaseDate            ReleasePlace Version  \
# 0                          NaN                     NaN     NaN
# 1                          NaN                     NaN     NaN
# 2                          NaN                     NaN     NaN
# 3                          NaN                     NaN       1
# 4     2019-05-15T00:00:00.000Z  Camp Springs, MD (USA)    2.70
# ...                        ...                     ...     ...
# 9013                       NaN                     NaN     NaN
# 9014                       NaN                     NaN     NaN
# 9015                       NaN                     NaN     NaN
# 9016                       NaN                     NaN     NaN
# 9017                       NaN                     NaN     NaN
#
#                                                 Linkage
# 0     https://doi.org/10.5067/SeaBASS/2009OCT_CHESAP...
# 1          https://doi.org/10.5067/IMPACTS/2DVD/DATA101
# 2          https://doi.org/10.5067/SeaBASS/AAOT/DATA001
# 3      https://doi.org/10.5067/ADEOS-II/AMSR/AA_L2A.001
# 4                   https://doi.org/10.5067/GHG16-2PO27
# ...                                                 ...
# 9013               https://doi.org/10.3334/ORNLDAAC/687
# 9014               https://doi.org/10.3334/ORNLDAAC/673
# 9015     https://doi.org/10.5067/IMPACTS/WISPER/DATA101
# 9016               https://doi.org/10.3334/ORNLDAAC/657
# 9017        https://doi.org/10.5067/IMPACTS/WRF/DATA101
#
# [9018 rows x 17 columns]

# %%
df.columns.values.tolist()
# Out:
# ['ShortName',
#  'EntryTitle',
#  'DOI',
#  'concept-id',
#  'provider-id',
#  's3-links',
#  'bbox-crs',
#  'bbox',
#  'horizontal_res',
#  'start-time',
#  'end-time',
#  'Creator',
#  'Publisher',
#  'ReleaseDate',
#  'ReleasePlace',
#  'Version',
#  'Linkage']
